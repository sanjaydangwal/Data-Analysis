# %%
import pandas as pd

# %%
titanic = pd.read_excel("titanic3.xls", usecols=["name", "sex", "age", "pclass", "fare"], index_col="name")
titanic
# Out:
#                                                  pclass     sex      age  \
# name
# Allen, Miss. Elisabeth Walton                         1  female  29.0000
# Allison, Master. Hudson Trevor                        1    male   0.9167
# Allison, Miss. Helen Loraine                          1  female   2.0000
# Allison, Mr. Hudson Joshua Creighton                  1    male  30.0000
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female  25.0000
# ...                                                 ...     ...      ...
# Zabour, Miss. Hileni                                  3  female  14.5000
# Zabour, Miss. Thamine                                 3  female      NaN
# Zakarian, Mr. Mapriededer                             3    male  26.5000
# Zakarian, Mr. Ortin                                   3    male  27.0000
# Zimmerman, Mr. Leo                                    3    male  29.0000
#
#                                                      fare
# name
# ...

# %%
titanic.iloc[0]
# Out:
# pclass           1
# sex         female
# age           29.0
# fare      211.3375
# Name: Allen, Miss. Elisabeth Walton, dtype: object

# %%
titanic.iloc[0:6]
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5       1                              Anderson, Mr. Harry    male  48.0000
#
#        fare
# 0  211.3375
# 1  151.5500
# 2  151.5500
# 3  151.5500
# 4  151.5500
# 5   26.5500

# %%
titanic.iloc[0:6:2]
# Out:
#                                                  pclass     sex   age  \
# name
# Allen, Miss. Elisabeth Walton                         1  female  29.0
# Allison, Miss. Helen Loraine                          1  female   2.0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female  25.0
#
#                                                      fare
# name
# Allen, Miss. Elisabeth Walton                    211.3375
# Allison, Miss. Helen Loraine                     151.5500
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  151.5500

# %%
titanic.iloc[[100, 200, 300]]
# Out:
#                                               pclass   sex   age     fare
# name
# Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")       1  male  49.0  56.9292
# McCaffry, Mr. Thomas Francis                       1  male  46.0  75.2417
# Van der hoef, Mr. Wyckoff                          1  male  61.0  33.5000

# %%
titanic.iloc[-3:]
# Out:
#                            pclass   sex   age   fare
# name
# Zakarian, Mr. Mapriededer       3  male  26.5  7.225
# Zakarian, Mr. Ortin             3  male  27.0  7.225
# Zimmerman, Mr. Leo              3  male  29.0  7.875

# %%
titanic = titanic.reset_index()

# %%
titanic.head(10)
# Out:
#                                               name  pclass     sex      age  \
# 0                    Allen, Miss. Elisabeth Walton       1  female  29.0000
# 1                   Allison, Master. Hudson Trevor       1    male   0.9167
# 2                     Allison, Miss. Helen Loraine       1  female   2.0000
# 3             Allison, Mr. Hudson Joshua Creighton       1    male  30.0000
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female  25.0000
# 5                              Anderson, Mr. Harry       1    male  48.0000
# 6                Andrews, Miss. Kornelia Theodosia       1  female  63.0000
# 7                           Andrews, Mr. Thomas Jr       1    male  39.0000
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)       1  female  53.0000
# 9                          Artagaveytia, Mr. Ramon       1    male  71.0000
#
#        fare
# 0  211.3375
# 1  151.5500
# 2  151.5500
# 3  151.5500
# 4  151.5500
# 5   26.5500
# 6   77.9583
# 7    0.0000
# ...

# %%
titanic.iloc[5, 3]
# Out:
# np.float64(48.0)

# %%
titanic.iloc[[4, 5, 6], 3]
# Out:
# 4    25.0
# 5    48.0
# 6    63.0
# Name: age, dtype: float64

# %%
titanic.iloc[5, [0, 1, 2]]
# Out:
# name      Anderson, Mr. Harry
# pclass                      1
# sex                      male
# Name: 5, dtype: object

# %%
titanic.iloc[[4, 5, 6], [0, 1, 2]]
# Out:
#                                               name  pclass     sex
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female
# 5                              Anderson, Mr. Harry       1    male
# 6                Andrews, Miss. Kornelia Theodosia       1  female

# %%
titanic.iloc[:, [0, 1, 2]]
# Out:
#                                                  name  pclass     sex
# 0                       Allen, Miss. Elisabeth Walton       1  female
# 1                      Allison, Master. Hudson Trevor       1    male
# 2                        Allison, Miss. Helen Loraine       1  female
# 3                Allison, Mr. Hudson Joshua Creighton       1    male
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  female
# ...                                               ...     ...     ...
# 1304                             Zabour, Miss. Hileni       3  female
# 1305                            Zabour, Miss. Thamine       3  female
# 1306                        Zakarian, Mr. Mapriededer       3    male
# 1307                              Zakarian, Mr. Ortin       3    male
# 1308                               Zimmerman, Mr. Leo       3    male
#
# [1309 rows x 3 columns]
