# %%
import pandas as pd

# %%
pokemons = pd.read_csv("Pokemon.csv", index_col="#")
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemons.agg({"Attack" : "mean", "Defense": "max"})
# Out:
# Attack      79.00125
# Defense    230.00000
# dtype: float64

# %%
pokemons.agg({"Attack" : ["mean", "max", "std"], "Defense": ["max", "min", "mean"]})
# Out:
#           Attack   Defense
# mean   79.001250   73.8425
# max   190.000000  230.0000
# std    32.457366       NaN
# min          NaN    5.0000

# %%
pokemons.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
pokemons.agg(["max", "min"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pokemons.agg(["max", "min"])
#
# File c:\Users\sanja\anaconda3\envs\MyEnv\Lib\site-packages\pandas\core\frame.py:10149, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#   10146 axis = self._get_axis_number(axis)
#   10148 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# > 10149 result = op.agg()
#   10150 result = reconstruct_and_relabel_result(result, func, **kwargs)
#   10151 return result
#
# File c:\Users\sanja\anaconda3\envs\MyEnv\Lib\site-packages\pandas\core\apply.py:928, in FrameApply.agg(self)
#     926 result = None
#     927 try:
# --> 928     result = super().agg()
#     929 finally:
#     930     self.obj = obj
#
# File c:\Users\sanja\anaconda3\envs\MyEnv\Lib\site-packages\pandas\core\apply.py:193, in Apply.agg(self)
# ...
