# %%
import pandas as pd

# %%
titanic = pd.read_excel("titanic3.xls", index_col="name")
titanic
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
#                                                      age  sibsp  parch  \
# ...

# %%
titanic.sort_index(inplace=True)
titanic
# Out:
#                                                pclass  survived     sex   age  \
# name
# Abbing, Mr. Anthony                                 3         0    male  42.0
# Abbott, Master. Eugene Joseph                       3         0    male  13.0
# Abbott, Mr. Rossmore Edward                         3         0    male  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)                    3         1  female  35.0
# Abelseth, Miss. Karen Marie                         3         1  female  16.0
# ...                                               ...       ...     ...   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female  24.0
# van Billiard, Master. James William                 3         0    male   NaN
# van Billiard, Master. Walter John                   3         0    male  11.5
# van Billiard, Mr. Austin Blyler                     3         0    male  40.5
# van Melkebeke, Mr. Philemon                         3         0    male   NaN
#
# ...

# %%
titanic.loc["Abbott, Mr. Rossmore Edward"]
# Out:
# pclass                         3
# survived                       0
# sex                         male
# age                         16.0
# sibsp                          1
# parch                          1
# ticket                 C.A. 2673
# fare                       20.25
# cabin                        NaN
# embarked                       S
# boat                         NaN
# body                       190.0
# home.dest    East Providence, RI
# Name: Abbott, Mr. Rossmore Edward, dtype: object

# %%
titanic.loc[["Abbott, Mr. Rossmore Edward", "Abelseth, Miss. Karen Marie"]]
# Out:
#                              pclass  survived     sex   age  sibsp  parch  \
# name
# Abbott, Mr. Rossmore Edward       3         0    male  16.0      1      1
# Abelseth, Miss. Karen Marie       3         1  female  16.0      0      0
#
#                                 ticket   fare cabin embarked boat   body  \
# name
# Abbott, Mr. Rossmore Edward  C.A. 2673  20.25   NaN        S  NaN  190.0
# Abelseth, Miss. Karen Marie     348125   7.65   NaN        S   16    NaN
#
#                                           home.dest
# name
# Abbott, Mr. Rossmore Edward     East Providence, RI
# Abelseth, Miss. Karen Marie  Norway Los Angeles, CA

# %%
titanic.loc["Abelseth, Miss. Karen Marie", ["fare", "sex", "cabin"]]
# Out:
# fare       7.65
# sex      female
# cabin       NaN
# Name: Abelseth, Miss. Karen Marie, dtype: object

# %%
titanic.loc[["Abelseth, Miss. Karen Marie", "Abbott, Mr. Rossmore Edward"], "fare"]
# Out:
# name
# Abelseth, Miss. Karen Marie     7.65
# Abbott, Mr. Rossmore Edward    20.25
# Name: fare, dtype: float64

# %%
pasangers = ["Abelseth, Miss. Karen Marie", "Abbott, Mr. Rossmore Edward"]

# %%
titanic.loc[pasangers, ["fare", "sex", "cabin"]]
# Out:
#                               fare     sex cabin
# name
# Abelseth, Miss. Karen Marie   7.65  female   NaN
# Abbott, Mr. Rossmore Edward  20.25    male   NaN
