# %%
import pandas as pd

# %%
pokemons = pd.read_csv("Pokemon.csv", index_col="#")
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 1         65       65     45           1      False
# 2         80       80     60           1      False
# 3        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 719      100      150     50           6       True
# 719      160      110    110           6       True
# 720      150      130     70           6       True
# 720      170      130     80           6       True
# 721      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
pokemons["name_length"] = pokemons["Name"].apply(len)
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_length
# #
# 1         65       65     45           1      False            9
# 2         80       80     60           1      False            7
# 3        100      100     80           1      False            8
# 3        122      120     80           1      False           21
# 4         60       50     65           1      False           10
# ..       ...      ...    ...         ...        ...          ...
# 719      100      150     50           6       True            7
# 719      160      110    110           6       True           19
# 720      150      130     70           6       True           19
# 720      170      130     80           6       True           18
# 721      130       90     70           6       True            9
#
# [800 rows x 13 columns]

# %%
pokemons["name_length"]
# Out:
# #
# 1       9
# 2       7
# 3       8
# 3      21
# 4      10
#        ..
# 719     7
# 719    19
# 720    19
# 720    18
# 721     9
# Name: name_length, Length: 800, dtype: int64

# %%
def strength(attack:int) -> str:
    if attack > 150:
        return "Stromg"
    elif attack > 100:
        return "Average"
    else:
        return "Week"

# %%
pokemons["Strength"] = pokemons["Attack"].apply(strength)
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_length Strength
# #
# 1         65       65     45           1      False            9     Week
# 2         80       80     60           1      False            7     Week
# 3        100      100     80           1      False            8     Week
# 3        122      120     80           1      False           21     Week
# 4         60       50     65           1      False           10     Week
# ..       ...      ...    ...         ...        ...          ...      ...
# 719      100      150     50           6       True            7     Week
# 719      160      110    110           6       True           19   Stromg
# 720      150      130     70           6       True           19  Average
# 720      170      130     80           6       True           18   Stromg
# 721      130       90     70           6       True            9  Average
#
# [800 rows x 14 columns]

# %%
del pokemons["name_length"]

# %%
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary Strength
# #
# 1         65       65     45           1      False     Week
# 2         80       80     60           1      False     Week
# 3        100      100     80           1      False     Week
# 3        122      120     80           1      False     Week
# 4         60       50     65           1      False     Week
# ..       ...      ...    ...         ...        ...      ...
# 719      100      150     50           6       True     Week
# 719      160      110    110           6       True   Stromg
# 720      150      130     70           6       True  Average
# 720      170      130     80           6       True   Stromg
# 721      130       90     70           6       True  Average
#
# [800 rows x 13 columns]

# %%
pokemons["Strength"].value_counts()
# Out:
# Strength
# Week       630
# Average    152
# Stromg      18
# Name: count, dtype: int64

# %%
del pokemons["Strength"]

# %%
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 1         65       65     45           1      False
# 2         80       80     60           1      False
# 3        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 719      100      150     50           6       True
# 719      160      110    110           6       True
# 720      150      130     70           6       True
# 720      170      130     80           6       True
# 721      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
def score(row):
    attack: int = row["Attack"]
    defence: int = row["Defense"]
    speed: int = row["Speed"]
    return sum([attack, defence, speed])

# %%
pokemons["score"] = pokemons.apply(score, axis=1)
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  score
# #
# 1         65       65     45           1      False    143
# 2         80       80     60           1      False    185
# 3        100      100     80           1      False    245
# 3        122      120     80           1      False    303
# 4         60       50     65           1      False    160
# ..       ...      ...    ...         ...        ...    ...
# 719      100      150     50           6       True    300
# 719      160      110    110           6       True    380
# 720      150      130     70           6       True    240
# 720      170      130     80           6       True    300
# 721      130       90     70           6       True    300
#
# [800 rows x 13 columns]

# %%
short_name = pokemons["Name"].apply(lambda name: name[:5])
short_name
# Out:
# #
# 1      Bulba
# 2      Ivysa
# 3      Venus
# 3      Venus
# 4      Charm
#        ...
# 719    Dianc
# 719    Dianc
# 720    Hoopa
# 720    Hoopa
# 721    Volca
# Name: Name, Length: 800, dtype: object
